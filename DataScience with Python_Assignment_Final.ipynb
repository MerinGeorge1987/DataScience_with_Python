# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#1.Import the data set in Python.
Mhousing=pd.read_csv("E:/4. OT Domain Practice/Digital Technologist Training/Datascience with Python/melbourne-housing-market/Melbourne_housing_FULL.csv")

# %%
#2.View the dataset
Mhousing
# Out:
#                    Suburb              Address  Rooms Type      Price Method  \
# 0              Abbotsford        68 Studley St      2    h        NaN     SS
# 1              Abbotsford         85 Turner St      2    h  1480000.0      S
# 2              Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3              Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 4              Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5              Abbotsford     40 Federation La      3    h   850000.0     PI
# 6              Abbotsford          55a Park St      4    h  1600000.0     VB
# 7              Abbotsford         16 Maugie St      4    h        NaN     SN
# 8              Abbotsford         53 Turner St      2    h        NaN      S
# 9              Abbotsford         99 Turner St      2    h        NaN      S
# 10             Abbotsford       129 Charles St      2    h   941000.0      S
# 11             Abbotsford         124 Yarra St      3    h  1876000.0      S
# 12             Abbotsford  121/56 Nicholson St      2    u        NaN     PI
# 13             Abbotsford        17 Raphael St      4    h        NaN      W
# 14             Abbotsford        98 Charles St      2    h  1636000.0      S
# 15             Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16             Abbotsford      18a Mollison St      2    t   745000.0      S
# 17             Abbotsford   6/241 Nicholson St      1    u   300000.0      S
# 18             Abbotsford        10 Valiant St      2    h  1097000.0      S
# 19             Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 20             Abbotsford            2 Rich St      2    h        NaN     SP
# 21             Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22             Abbotsford    106/119 Turner St      1    u   481000.0     SP
# 23             Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB
# 24             Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# 25             Abbotsford  123/56 Nicholson St      2    u   750000.0      S
# 26             Abbotsford           22 Park St      4    h  1985000.0      S
# 27             Abbotsford    13/84 Trenerry Cr      1    u   500000.0      S
# 28             Abbotsford        45 William St      2    h  1172500.0      S
# 29             Abbotsford   7/20 Abbotsford St      1    u   441000.0     SP
# ...                   ...                  ...    ...  ...        ...    ...
# 34827      West Footscray         13 Barton St      4    h  1096000.0      S
# 34828      West Footscray          30 Gwelo St      3    h   900000.0     PI
# 34829      West Melbourne     9/11 Anderson St      3    u        NaN      S
# 34830      West Melbourne       122 Railway Pl      3    t  1150000.0      S
# 34831         Westmeadows        35 Arnside Cr      4    h   675000.0      S
# 34832         Westmeadows        2/8 Forman St      4    u   689000.0      S
# 34833       Wheelers Hill     45 Chancellor Dr      4    h   936000.0      S
# 34834       Wheelers Hill         112 Jells Rd      4    h        NaN     PN
# 34835       Wheelers Hill           20 Mill Ct      3    h        NaN      S
# 34836       Wheelers Hill          9 Walden Av      5    h  1400000.0      S
# 34837        Williamstown      13 Kingshott Cl      5    h  2020000.0      S
# 34838        Williamstown   11/81 Melbourne Rd      2    u   450000.0     SP
# 34839        Williamstown     24/18 Station Rd      2    u   475000.0     SP
# 34840        Williamstown      3/2 Thompson St      2    u   520000.0     VB
# 34841        Williamstown        5 Thompson St      2    h   940000.0     VB
# 34842        Williamstown        34 Twyford St      3    h  1400000.0     SP
# 34843  Williamstown North          32 Edina St      3    h   830000.0      S
# 34844             Windsor     4/16 Lewisham Rd      1    u   440000.0     SP
# 34845             Windsor           13 Mary St      4    h        NaN      W
# 34846             Wollert           10 Alma Rd      4    h   630000.0     SP
# 34847             Wollert      27 Birchmore Rd      3    h   500000.0     PI
# 34848             Wollert        16 Gunther Wy      4    h   621000.0      S
# 34849             Wollert      35 Kingscote Wy      3    h   570000.0     SP
# 34850             Wollert     15 Rockgarden Wy      3    h        NaN     SP
# 34851          Yarraville        78 Bayview Rd      3    h  1101000.0      S
# 34852          Yarraville          13 Burns St      4    h  1480000.0     PI
# 34853          Yarraville        29A Murray St      2    h   888000.0     SP
# 34854          Yarraville       147A Severn St      2    t   705000.0      S
# 34855          Yarraville     12/37 Stephen St      3    h  1140000.0     SP
# 34856          Yarraville     3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode      ...       Bathroom  \
# 0             Jellis    3/9/2016       2.5    3067.0      ...            1.0
# 1             Biggin   3/12/2016       2.5    3067.0      ...            1.0
# 2             Biggin    4/2/2016       2.5    3067.0      ...            1.0
# 3             Rounds    4/2/2016       2.5    3067.0      ...            2.0
# 4             Biggin    4/3/2017       2.5    3067.0      ...            2.0
# 5             Biggin    4/3/2017       2.5    3067.0      ...            2.0
# 6             Nelson    4/6/2016       2.5    3067.0      ...            1.0
# 7             Nelson    6/8/2016       2.5    3067.0      ...            2.0
# 8             Biggin    6/8/2016       2.5    3067.0      ...            1.0
# 9            Collins    6/8/2016       2.5    3067.0      ...            2.0
# 10            Jellis    7/5/2016       2.5    3067.0      ...            1.0
# 11            Nelson    7/5/2016       2.5    3067.0      ...            2.0
# 12            Biggin   7/11/2016       2.5    3067.0      ...            2.0
# 13            Biggin   7/11/2016       2.5    3067.0      ...            2.0
# 14            Nelson   8/10/2016       2.5    3067.0      ...            1.0
# 15            Jellis   8/10/2016       2.5    3067.0      ...            NaN
# 16            Jellis   8/10/2016       2.5    3067.0      ...            NaN
# 17            Biggin   8/10/2016       2.5    3067.0      ...            1.0
# 18            Biggin   8/10/2016       2.5    3067.0      ...            1.0
# 19            Dingle   8/10/2016       2.5    3067.0      ...            NaN
# 20            Biggin  10/12/2016       2.5    3067.0      ...            1.0
# 21            Biggin  10/12/2016       2.5    3067.0      ...            NaN
# 22      Purplebricks  10/12/2016       2.5    3067.0      ...            NaN
# 23            Jellis  12/11/2016       2.5    3067.0      ...            2.0
# 24            Nelson  12/11/2016       2.5    3067.0      ...            2.0
# 25            Biggin  12/11/2016       2.5    3067.0      ...            2.0
# 26            Biggin  12/11/2016       2.5    3067.0      ...            NaN
# 27            Biggin  12/11/2016       2.5    3067.0      ...            NaN
# 28            Biggin  13/08/2016       2.5    3067.0      ...            1.0
# 29              Greg  14/05/2016       2.5    3067.0      ...            1.0
# ...              ...         ...       ...       ...      ...            ...
# 34827            Jas  24/02/2018       6.4    3012.0      ...            1.0
# 34828        Village  24/02/2018       6.4    3012.0      ...            1.0
# 34829  hockingstuart  24/02/2018       3.1    3003.0      ...            NaN
# 34830         Jellis  24/02/2018       3.1    3003.0      ...            2.0
# 34831            YPA  24/02/2018      16.5    3049.0      ...            2.0
# 34832            YPA  24/02/2018      16.5    3049.0      ...            NaN
# 34833          Barry  24/02/2018      16.7    3150.0      ...            2.0
# 34834      Harcourts  24/02/2018      16.7    3150.0      ...            2.0
# 34835          Barry  24/02/2018      16.7    3150.0      ...            2.0
# 34836            LLC  24/02/2018      16.7    3150.0      ...            2.0
# 34837           Greg  24/02/2018       6.8    3016.0      ...            3.0
# 34838          Raine  24/02/2018       6.8    3016.0      ...            NaN
# 34839           Greg  24/02/2018       6.8    3016.0      ...            NaN
# 34840          Raine  24/02/2018       6.8    3016.0      ...            NaN
# 34841       Williams  24/02/2018       6.8    3016.0      ...            2.0
# 34842        Sweeney  24/02/2018       6.8    3016.0      ...            2.0
# 34843  hockingstuart  24/02/2018       6.8    3016.0      ...            1.0
# 34844         Biggin  24/02/2018       4.6    3181.0      ...            NaN
# 34845         Jellis  24/02/2018       4.6    3181.0      ...            3.0
# 34846  hockingstuart  24/02/2018      25.5    3750.0      ...            2.0
# 34847            Ray  24/02/2018      25.5    3750.0      ...            2.0
# 34848  hockingstuart  24/02/2018      25.5    3750.0      ...            2.0
# 34849             RW  24/02/2018      25.5    3750.0      ...            2.0
# 34850             LJ  24/02/2018      25.5    3750.0      ...            2.0
# 34851            Jas  24/02/2018       6.3    3013.0      ...            1.0
# 34852            Jas  24/02/2018       6.3    3013.0      ...            1.0
# 34853        Sweeney  24/02/2018       6.3    3013.0      ...            2.0
# 34854            Jas  24/02/2018       6.3    3013.0      ...            1.0
# 34855  hockingstuart  24/02/2018       6.3    3013.0      ...            NaN
# 34856             RW  24/02/2018       6.3    3013.0      ...            1.0
#
#        Car  Landsize  BuildingArea  YearBuilt                CouncilArea  \
# 0      1.0     126.0           NaN        NaN         Yarra City Council
# 1      1.0     202.0           NaN        NaN         Yarra City Council
# 2      0.0     156.0          79.0     1900.0         Yarra City Council
# 3      1.0       0.0           NaN        NaN         Yarra City Council
# 4      0.0     134.0         150.0     1900.0         Yarra City Council
# 5      1.0      94.0           NaN        NaN         Yarra City Council
# 6      2.0     120.0         142.0     2014.0         Yarra City Council
# 7      2.0     400.0         220.0     2006.0         Yarra City Council
# 8      2.0     201.0           NaN     1900.0         Yarra City Council
# 9      1.0     202.0           NaN     1900.0         Yarra City Council
# 10     0.0     181.0           NaN        NaN         Yarra City Council
# 11     0.0     245.0         210.0     1910.0         Yarra City Council
# 12     1.0    4292.0          82.0     2009.0         Yarra City Council
# 13     0.0     230.0         147.0     1860.0         Yarra City Council
# 14     2.0     256.0         107.0     1890.0         Yarra City Council
# 15     NaN       NaN           NaN        NaN         Yarra City Council
# 16     NaN       NaN           NaN        NaN         Yarra City Council
# 17     1.0       0.0           NaN        NaN         Yarra City Council
# 18     2.0     220.0          75.0     1900.0         Yarra City Council
# 19     NaN       NaN           NaN        NaN         Yarra City Council
# 20     1.0     176.0          80.0     1925.0         Yarra City Council
# 21     NaN       NaN           NaN        NaN         Yarra City Council
# 22     NaN       NaN           NaN        NaN         Yarra City Council
# 23     1.0       0.0           NaN        NaN         Yarra City Council
# 24     2.0     214.0         190.0     2005.0         Yarra City Council
# 25     1.0       0.0          94.0     2009.0         Yarra City Council
# 26     NaN       NaN           NaN        NaN         Yarra City Council
# 27     NaN       NaN           NaN        NaN         Yarra City Council
# 28     1.0     195.0           NaN        NaN         Yarra City Council
# 29     1.0       0.0           NaN        NaN         Yarra City Council
# ...    ...       ...           ...        ...                        ...
# 34827  3.0     368.0           NaN        NaN   Maribyrnong City Council
# 34828  2.0     460.0         112.0     1940.0   Maribyrnong City Council
# 34829  NaN       NaN           NaN        NaN     Melbourne City Council
# 34830  2.0     678.0           NaN        NaN     Melbourne City Council
# 34831  5.0     560.0         148.0     1980.0          Hume City Council
# 34832  NaN       NaN           NaN        NaN          Hume City Council
# 34833  2.0     770.0           NaN        NaN        Monash City Council
# 34834  2.0     714.0           NaN        NaN        Monash City Council
# 34835  2.0     677.0           NaN        NaN        Monash City Council
# 34836  2.0     739.0         293.0     1980.0        Monash City Council
# 34837  2.0     450.0         241.0     2015.0   Hobsons Bay City Council
# 34838  NaN       NaN           NaN        NaN   Hobsons Bay City Council
# 34839  NaN       NaN           NaN        NaN   Hobsons Bay City Council
# 34840  NaN       NaN           NaN        NaN   Hobsons Bay City Council
# 34841  1.0     122.0           NaN     1999.0   Hobsons Bay City Council
# 34842  NaN     325.0         158.0     1995.0   Hobsons Bay City Council
# 34843  2.0     345.0           NaN     1949.0   Hobsons Bay City Council
# 34844  NaN       NaN           NaN        NaN  Port Phillip City Council
# 34845  2.0     279.0         237.0     2009.0  Port Phillip City Council
# 34846  2.0     388.0           NaN        NaN    Whittlesea City Council
# 34847  2.0     383.0         118.0     2016.0    Whittlesea City Council
# 34848  2.0     375.0           NaN        NaN    Whittlesea City Council
# 34849  2.0     404.0         158.0     2012.0    Whittlesea City Council
# 34850  2.0     268.0         135.0     2016.0    Whittlesea City Council
# 34851  NaN     288.0           NaN        NaN   Maribyrnong City Council
# 34852  3.0     593.0           NaN        NaN   Maribyrnong City Council
# 34853  1.0      98.0         104.0     2018.0   Maribyrnong City Council
# 34854  2.0     220.0         120.0     2000.0   Maribyrnong City Council
# 34855  NaN       NaN           NaN        NaN   Maribyrnong City Council
# 34856  0.0     250.0         103.0     1930.0   Maribyrnong City Council
#
#       Lattitude  Longtitude                  Regionname Propertycount
# 0     -37.80140   144.99580       Northern Metropolitan        4019.0
# 1     -37.79960   144.99840       Northern Metropolitan        4019.0
# 2     -37.80790   144.99340       Northern Metropolitan        4019.0
# 3     -37.81140   145.01160       Northern Metropolitan        4019.0
# 4     -37.80930   144.99440       Northern Metropolitan        4019.0
# 5     -37.79690   144.99690       Northern Metropolitan        4019.0
# 6     -37.80720   144.99410       Northern Metropolitan        4019.0
# 7     -37.79650   144.99650       Northern Metropolitan        4019.0
# 8     -37.79950   144.99740       Northern Metropolitan        4019.0
# 9     -37.79960   144.99890       Northern Metropolitan        4019.0
# 10    -37.80410   144.99530       Northern Metropolitan        4019.0
# 11    -37.80240   144.99930       Northern Metropolitan        4019.0
# 12    -37.80780   144.99650       Northern Metropolitan        4019.0
# 13    -37.80660   144.99360       Northern Metropolitan        4019.0
# 14    -37.80600   144.99540       Northern Metropolitan        4019.0
# 15          NaN         NaN       Northern Metropolitan        4019.0
# 16          NaN         NaN       Northern Metropolitan        4019.0
# 17    -37.80080   144.99730       Northern Metropolitan        4019.0
# 18    -37.80100   144.99890       Northern Metropolitan        4019.0
# 19          NaN         NaN       Northern Metropolitan        4019.0
# 20    -37.79980   144.99720       Northern Metropolitan        4019.0
# 21          NaN         NaN       Northern Metropolitan        4019.0
# 22          NaN         NaN       Northern Metropolitan        4019.0
# 23    -37.81100   145.00670       Northern Metropolitan        4019.0
# 24    -37.80850   144.99640       Northern Metropolitan        4019.0
# 25    -37.80780   144.99650       Northern Metropolitan        4019.0
# 26    -37.80840   144.99420       Northern Metropolitan        4019.0
# 27          NaN         NaN       Northern Metropolitan        4019.0
# 28    -37.80840   144.99730       Northern Metropolitan        4019.0
# 29    -37.80160   144.99880       Northern Metropolitan        4019.0
# ...         ...         ...                         ...           ...
# 34827 -37.79152   144.87277        Western Metropolitan        5058.0
# 34828 -37.80139   144.86458        Western Metropolitan        5058.0
# 34829       NaN         NaN       Northern Metropolitan        2230.0
# 34830 -37.80787   144.94334       Northern Metropolitan        2230.0
# 34831 -37.68089   144.87403       Northern Metropolitan        2474.0
# 34832       NaN         NaN       Northern Metropolitan        2474.0
# 34833 -37.91637   145.18062  South-Eastern Metropolitan        7392.0
# 34834 -37.90287   145.19011  South-Eastern Metropolitan        7392.0
# 34835 -37.91905   145.19105  South-Eastern Metropolitan        7392.0
# 34836 -37.89304   145.18475  South-Eastern Metropolitan        7392.0
# 34837 -37.86180   144.87855        Western Metropolitan        6380.0
# 34838       NaN         NaN        Western Metropolitan        6380.0
# 34839       NaN         NaN        Western Metropolitan        6380.0
# 34840       NaN         NaN        Western Metropolitan        6380.0
# 34841 -37.86396   144.90541        Western Metropolitan        6380.0
# 34842 -37.86871   144.90124        Western Metropolitan        6380.0
# 34843 -37.85545   144.88118        Western Metropolitan         802.0
# 34844       NaN         NaN       Southern Metropolitan        4380.0
# 34845 -37.85418   144.99697       Southern Metropolitan        4380.0
# 34846 -37.60981   145.04135       Northern Metropolitan        2940.0
# 34847 -37.61940   145.03951       Northern Metropolitan        2940.0
# 34848 -37.61331   145.03412       Northern Metropolitan        2940.0
# 34849 -37.61031   145.03393       Northern Metropolitan        2940.0
# 34850 -37.61094   145.04281       Northern Metropolitan        2940.0
# 34851 -37.81095   144.88516        Western Metropolitan        6543.0
# 34852 -37.81053   144.88467        Western Metropolitan        6543.0
# 34853 -37.81551   144.88826        Western Metropolitan        6543.0
# 34854 -37.82286   144.87856        Western Metropolitan        6543.0
# 34855       NaN         NaN        Western Metropolitan        6543.0
# 34856 -37.81810   144.89351        Western Metropolitan        6543.0
#
# [34857 rows x 21 columns]

# %%
#3.See the structure and the summary of the dataset to understand the data.
Mhousing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34857 non-null object
# Address          34857 non-null object
# Rooms            34857 non-null int64
# Type             34857 non-null object
# Price            27247 non-null float64
# Method           34857 non-null object
# SellerG          34857 non-null object
# Date             34857 non-null object
# Distance         34856 non-null float64
# Postcode         34856 non-null float64
# Bedroom2         26640 non-null float64
# Bathroom         26631 non-null float64
# Car              26129 non-null float64
# Landsize         23047 non-null float64
# BuildingArea     13742 non-null float64
# YearBuilt        15551 non-null float64
# CouncilArea      34854 non-null object
# Lattitude        26881 non-null float64
# Longtitude       26881 non-null float64
# Regionname       34854 non-null object
# Propertycount    34854 non-null float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.6+ MB

# %%
Mhousing.shape
# Out:
# (34857, 21)

# %%
Mhousing.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
Mhousing.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# std        0.724212      1.010771    3398.841946     401.26706     37.328178
# min        0.000000      0.000000       0.000000       0.00000   1196.000000
# 25%        1.000000      1.000000     224.000000     102.00000   1940.000000
# 50%        2.000000      2.000000     521.000000     136.00000   1970.000000
# 75%        2.000000      2.000000     670.000000     188.00000   2000.000000
# max       12.000000     26.000000  433014.000000   44515.00000   2106.000000
#
#           Lattitude    Longtitude  Propertycount
# count  26881.000000  26881.000000   34854.000000
# mean     -37.810634    145.001851    7572.888306
# std        0.090279      0.120169    4428.090313
# min      -38.190430    144.423790      83.000000
# 25%      -37.862950    144.933500    4385.000000
# 50%      -37.807600    145.007800    6763.000000
# 75%      -37.754100    145.071900   10412.000000
# max      -37.390200    145.526350   21650.000000

# %%
#4.	Find out the number of: a.) Numeric attributes   b.) Categorical attributes:
a=0;b=0
for col in Mhousing:
    if Mhousing[col].dtype!='object':
        a=a+1
    if Mhousing[col].dtype=='object':
        b=b+1
print ("Number of Numeric attributes:",a)
print ("Number of Categorical attributes:",b)
# Out:
# Number of Numeric attributes: 13
# Number of Categorical attributes: 8

# %%
#Duplicate values: Identify if the datasets have duplicate values or not and remove the duplicate values. 
#Find out the number of rows present in the dataset: a)Before removing duplicate values  b)After removing duplicate values

Mhousing_dup = Mhousing.drop_duplicates()
if len(Mhousing)!=len(Mhousing_dup):
    print ("Duplicates detected in the dataset")
    print ("Number of rows before removing duplicate values",len(Mhousing))
    print ("Number of rows after removing duplicate values",len(Mhousing_dup))
else:
    print ("Duplicates not detected")
# Out:
# Duplicates detected in the dataset
# Number of rows before removing duplicate values 34857
# Number of rows after removing duplicate values 34856

# %%
#Missing value treatment: Check which variables have missing values and use appropriate treatments. 
#For each of the variables, find the number of missing values and provide the value that they have been imputed with.

#SOLUTION: Finding variables with missing values & the number of missing values for each variable
for col in Mhousing:   
    if (Mhousing[col].isnull().values.any()):       
        print('\n',col,"has missing values")
        print("Number of missing values:",Mhousing[col].isnull().sum())
# Out:
#  Price has missing values
# Number of missing values: 7610
#
#  Distance has missing values
# Number of missing values: 1
#
#  Postcode has missing values
# Number of missing values: 1
#
#  Bedroom2 has missing values
# Number of missing values: 8217
#
#  Bathroom has missing values
# Number of missing values: 8226
#
#  Car has missing values
# Number of missing values: 8728
#
#  Landsize has missing values
# Number of missing values: 11810
#
#  BuildingArea has missing values
# Number of missing values: 21115
#
#  YearBuilt has missing values
# Number of missing values: 19306
#
#  CouncilArea has missing values
# Number of missing values: 3
#
#  Lattitude has missing values
# Number of missing values: 7976
#
#  Longtitude has missing values
# Number of missing values: 7976
#
#  Regionname has missing values
# Number of missing values: 3
#
#  Propertycount has missing values
# Number of missing values: 3

# %%
#SOLUTION: Filling above missing values (mean value for numerics, 0 for Postcode and YearBuilt & 'Random' for string)
Mhousing.Price=Mhousing.Price.fillna(1.050173e+06)
Mhousing.Distance=Mhousing.Distance.fillna(11)
Mhousing.Postcode=Mhousing.Postcode.fillna(0)
Mhousing.Bedroom2=Mhousing.Bedroom2.fillna(3)
Mhousing.Bathroom=Mhousing.Bathroom.fillna(2)
Mhousing.Car=Mhousing.Car.fillna(2)
Mhousing.Landsize=Mhousing.Landsize.fillna(593)
Mhousing.BuildingArea=Mhousing.BuildingArea.fillna(160)
Mhousing.YearBuilt=Mhousing.YearBuilt.fillna(0)
Mhousing.CouncilArea=Mhousing.CouncilArea.fillna('Random')
Mhousing.Lattitude=Mhousing.Lattitude.fillna(0)
Mhousing.Longtitude=Mhousing.Longtitude.fillna(0)
Mhousing.Regionname=Mhousing.Regionname.fillna('Random')
Mhousing.Propertycount=Mhousing.Propertycount.fillna(0)

#DATA CHECK for anymore missing values
for col in Mhousing:   
    if (Mhousing[col].isnull().values.any()):       
        print('\n',col,"has missing values")
        print("Number of missing values:",Mhousing[col].isnull().sum())
    else:
        print ("No missing values for column", col)
# Out:
# No missing values for column Suburb
# No missing values for column Address
# No missing values for column Rooms
# No missing values for column Type
# No missing values for column Price
# No missing values for column Method
# No missing values for column SellerG
# No missing values for column Date
# No missing values for column Distance
# No missing values for column Postcode
# No missing values for column Bedroom2
# No missing values for column Bathroom
# No missing values for column Car
# No missing values for column Landsize
# No missing values for column BuildingArea
# No missing values for column YearBuilt
# No missing values for column CouncilArea
# No missing values for column Lattitude
# No missing values for column Longtitude
# No missing values for column Regionname
# No missing values for column Propertycount

# %%
#Variable type: Check if all the variables have the correct variable type, based on the data dictionary. If not, then change them.
#For how many attributes did you need to change the data type?

#SOLUTION: Data type of each variable
Mhousing.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
#As per data dictionary, 
##  $ Suburb       : Factor 
##  $ Rooms        : int  
##  $ Type         : Factor
##  $ Price        : int  
##  $ Method       : Factor
##  $ SellerG      : Factor 
##  $ Date         : Factor 
##  $ Distance     : num  
##  $ Postcode     : Factor 
##  $ Bedroom2     : int  
##  $ Bathroom     : int  
##  $ Car          : int  
##  $ Landsize     : int  
##  $ YearBuilt    : int  
##  $ Regionname   : Factor 
##  $ Propertycount: Factor 
# where Factor in R is equivalent to Category in pandas


#SOLUTION: collecting all columns with dtype as object & converting to category (except Address & Council Area)
obj_columns = Mhousing.select_dtypes(['object']).columns
cnt=0
for col in obj_columns:
    if (col!='Address' and col!='CouncilArea' ):
        Mhousing[col] = Mhousing[col].astype('category')
        cnt=cnt+1

#SOLUTION: converting dtype of Postcode & Propertycount to category
Mhousing.Postcode = Mhousing.Postcode.astype('category')
cnt=cnt+1
Mhousing.Propertycount = Mhousing.Propertycount.astype('category')
cnt=cnt+1
Mhousing.dtypes
# Out:
# Suburb           category
# Address            object
# Rooms               int64
# Type             category
# Price             float64
# Method           category
# SellerG          category
# Date             category
# Distance          float64
# Postcode         category
# Bedroom2          float64
# Bathroom          float64
# Car               float64
# Landsize          float64
# BuildingArea      float64
# YearBuilt         float64
# CouncilArea        object
# Lattitude         float64
# Longtitude        float64
# Regionname       category
# Propertycount    category
# dtype: object

# %%
#SOLUTION: collecting all columns with dtype as float64 & converting to int64 
fl_columns = Mhousing.select_dtypes(['float64']).columns
for col in fl_columns:
    Mhousing[col] = Mhousing[col].astype('int64')
    cnt=cnt+1

#Count 
print("Number of changes in datatype",cnt)
Mhousing.dtypes
# Out:
# Number of changes in datatype 18
# Suburb           category
# Address            object
# Rooms               int64
# Type             category
# Price               int64
# Method           category
# SellerG          category
# Date             category
# Distance            int64
# Postcode         category
# Bedroom2            int64
# Bathroom            int64
# Car                 int64
# Landsize            int64
# BuildingArea        int64
# YearBuilt           int64
# CouncilArea        object
# Lattitude           int64
# Longtitude          int64
# Regionname       category
# Propertycount    category
# dtype: object

# %%
#Outlier Treatment: 
#Identify the varibales : Make a subset of the dataset with all the numeric variables. 
#Outliers : For each variable of this subset, carry out the outlier detection.
#           Find out the percentile distribution of each variable and carry out capping and flooring for outlier values.  

#SOLUTION :a subset of the dataset with data tyep as int64. 
Mhousing_num=Mhousing.select_dtypes(['int64'])
Mhousing_num
# Out:
#        Rooms    Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0          2  1050173         2         2         1    1       126
# 1          2  1480000         2         2         1    1       202
# 2          2  1035000         2         2         1    0       156
# 3          3  1050173         2         3         2    1         0
# 4          3  1465000         2         3         2    0       134
# 5          3   850000         2         3         2    1        94
# 6          4  1600000         2         3         1    2       120
# 7          4  1050173         2         3         2    2       400
# 8          2  1050173         2         4         1    2       201
# 9          2  1050173         2         3         2    1       202
# 10         2   941000         2         2         1    0       181
# 11         3  1876000         2         4         2    0       245
# 12         2  1050173         2         2         2    1      4292
# 13         4  1050173         2         6         2    0       230
# 14         2  1636000         2         2         1    2       256
# 15         3  1000000         2         3         2    2       593
# 16         2   745000         2         3         2    2       593
# 17         1   300000         2         1         1    1         0
# 18         2  1097000         2         3         1    2       220
# 19         2   542000         2         3         2    2       593
# 20         2  1050173         2         2         1    1       176
# 21         2   760000         2         3         2    2       593
# 22         1   481000         2         3         2    2       593
# 23         2   700000         2         2         2    1         0
# 24         3  1350000         2         3         2    2       214
# 25         2   750000         2         2         2    1         0
# 26         4  1985000         2         3         2    2       593
# 27         1   500000         2         3         2    2       593
# 28         2  1172500         2         2         1    1       195
# 29         1   441000         2         1         1    1         0
# ...      ...      ...       ...       ...       ...  ...       ...
# 34827      4  1096000         6         4         1    3       368
# 34828      3   900000         6         3         1    2       460
# 34829      3  1050173         3         3         2    2       593
# 34830      3  1150000         3         3         2    2       678
# 34831      4   675000        16         4         2    5       560
# 34832      4   689000        16         3         2    2       593
# 34833      4   936000        16         4         2    2       770
# 34834      4  1050173        16         4         2    2       714
# 34835      3  1050173        16         3         2    2       677
# 34836      5  1400000        16         5         2    2       739
# 34837      5  2020000         6         5         3    2       450
# 34838      2   450000         6         3         2    2       593
# 34839      2   475000         6         3         2    2       593
# 34840      2   520000         6         3         2    2       593
# 34841      2   940000         6         2         2    1       122
# 34842      3  1400000         6         3         2    2       325
# 34843      3   830000         6         3         1    2       345
# 34844      1   440000         4         3         2    2       593
# 34845      4  1050173         4         4         3    2       279
# 34846      4   630000        25         4         2    2       388
# 34847      3   500000        25         3         2    2       383
# 34848      4   621000        25         4         2    2       375
# 34849      3   570000        25         3         2    2       404
# 34850      3  1050173        25         3         2    2       268
# 34851      3  1101000         6         3         1    2       288
# 34852      4  1480000         6         4         1    3       593
# 34853      2   888000         6         2         2    1        98
# 34854      2   705000         6         2         1    2       220
# 34855      3  1140000         6         3         2    2       593
# 34856      2  1020000         6         2         1    0       250
#
#        BuildingArea  YearBuilt  Lattitude  Longtitude
# 0               160          0        -37         144
# 1               160          0        -37         144
# 2                79       1900        -37         144
# 3               160          0        -37         145
# 4               150       1900        -37         144
# 5               160          0        -37         144
# 6               142       2014        -37         144
# 7               220       2006        -37         144
# 8               160       1900        -37         144
# 9               160       1900        -37         144
# 10              160          0        -37         144
# 11              210       1910        -37         144
# 12               82       2009        -37         144
# 13              147       1860        -37         144
# 14              107       1890        -37         144
# 15              160          0          0           0
# 16              160          0          0           0
# 17              160          0        -37         144
# 18               75       1900        -37         144
# 19              160          0          0           0
# 20               80       1925        -37         144
# 21              160          0          0           0
# 22              160          0          0           0
# 23              160          0        -37         145
# 24              190       2005        -37         144
# 25               94       2009        -37         144
# 26              160          0        -37         144
# 27              160          0          0           0
# 28              160          0        -37         144
# 29              160          0        -37         144
# ...             ...        ...        ...         ...
# 34827           160          0        -37         144
# 34828           112       1940        -37         144
# 34829           160          0          0           0
# 34830           160          0        -37         144
# 34831           148       1980        -37         144
# 34832           160          0          0           0
# 34833           160          0        -37         145
# 34834           160          0        -37         145
# 34835           160          0        -37         145
# 34836           293       1980        -37         145
# 34837           241       2015        -37         144
# 34838           160          0          0           0
# 34839           160          0          0           0
# 34840           160          0          0           0
# 34841           160       1999        -37         144
# 34842           158       1995        -37         144
# 34843           160       1949        -37         144
# 34844           160          0          0           0
# 34845           237       2009        -37         144
# 34846           160          0        -37         145
# 34847           118       2016        -37         145
# 34848           160          0        -37         145
# 34849           158       2012        -37         145
# 34850           135       2016        -37         145
# 34851           160          0        -37         144
# 34852           160          0        -37         144
# 34853           104       2018        -37         144
# 34854           120       2000        -37         144
# 34855           160          0          0           0
# 34856           103       1930        -37         144
#
# [34857 rows x 11 columns]

# %%
#SOLUTION:sample percentile distribution
print(Mhousing_num.quantile([.01,.02,.03,.04,.05,.1,.2,.4,.5,.95,.96,.99] ))

#SOLUTION:sample BoxPlot for variable "Rooms"
import seaborn as sns
sns.boxplot(x=Mhousing_num['Rooms'])
# Out:
#       Rooms      Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0.01    1.0   320000.0       1.0       1.0       1.0  0.0      0.00
# 0.02    1.0   363000.0       1.0       1.0       1.0  0.0      0.00
# 0.03    1.0   393000.0       2.0       2.0       1.0  0.0      0.00
# 0.04    1.0   417000.0       2.0       2.0       1.0  0.0      0.00
# 0.05    2.0   439000.0       2.0       2.0       1.0  1.0      0.00
# 0.10    2.0   519000.0       3.0       2.0       1.0  1.0    133.00
# 0.20    2.0   640000.0       5.0       3.0       1.0  1.0    278.00
# 0.40    3.0   885000.0       8.0       3.0       2.0  2.0    589.00
# 0.50    3.0  1050173.0      10.0       3.0       2.0  2.0    593.00
# 0.95    5.0  2055000.0      24.0       4.0       3.0  3.0    882.00
# 0.96    5.0  2220760.0      25.0       5.0       3.0  4.0    943.00
# 0.99    5.0  3225000.0      35.0       5.0       4.0  5.0   2030.76
#
#       BuildingArea  YearBuilt  Lattitude  Longtitude
# 0.01         41.56        0.0      -38.0         0.0
# 0.02         56.00        0.0      -37.0         0.0
# 0.03         66.00        0.0      -37.0         0.0
# 0.04         73.00        0.0      -37.0         0.0
# 0.05         79.00        0.0      -37.0         0.0
# 0.10        102.00        0.0      -37.0         0.0
# 0.20        137.00        0.0      -37.0         0.0
# 0.40        160.00        0.0      -37.0       144.0
# 0.50        160.00        0.0      -37.0       144.0
# 0.95        240.00     2010.0        0.0       145.0
# 0.96        256.76     2011.0        0.0       145.0
# 0.99        367.00     2015.0        0.0       145.0

# %%
sns.boxplot(x=Mhousing_num['Distance'])

# %%
sns.boxplot(x=Mhousing_num['Price'])

# %%
sns.boxplot(x=Mhousing_num['Bedroom2'])

# %%
sns.boxplot(x=Mhousing_num['Bathroom'])

# %%
sns.boxplot(x=Mhousing_num['Car'])

# %%
sns.boxplot(x=Mhousing_num['Landsize'])

# %%
sns.boxplot(x=Mhousing_num['BuildingArea'])

# %%
#SOLUTION: Outlier Detection & Capping and Flooring of Outlier Values using IQR method.
 

for col in Mhousing_num:
    #As Lattitude & Longitude will not affect the Price, not considering them for Outlier treatment
    if col!='Lattitude' and col!='Longtitude':
        print("\n\nOutlier Treatment for ",col)
       
        #Outlier Detection using IQR method where Cap=IQ3+1.5*IQR & Floor=1.5*IQR-IQ1
        Q1 = Mhousing_num[col].quantile(0.25)
        Q3 = Mhousing_num[col].quantile(0.75)
        IQR = Q3 - Q1
        print("IQR for ",col,"=",IQR)
        limit=1.5*IQR
        floor = limit - Q1
        print("Floor for ",col,"=",floor)
        Cap = Q3 + limit
        print("Cap for ",col,"=",Cap)
        
        #Removal of Outlier Values. i.e values less than (1.5*IQR-Q1) and more than (1.5*IQR+Q3) are removed.
        #Large number of Outliers are detected for Price. So Removing Outlier values for Price.
        if col=='Price':
            Mhousing_num=Mhousing_num[(Mhousing_num[col]>=floor)&(Mhousing_num[col]<=Cap)]
            print(Mhousing_num.shape)
# Out:
# Outlier Treatment for  Rooms
# IQR for  Rooms = 2.0
# Floor for  Rooms = 1.0
# Cap for  Rooms = 7.0
#
#
# Outlier Treatment for  Price
# IQR for  Price = 455000.0
# Floor for  Price = -12500.0
# Cap for  Price = 1832500.0
# (32301, 11)
#
#
# Outlier Treatment for  Distance
# IQR for  Distance = 8.0
# Floor for  Distance = 6.0
# Cap for  Distance = 26.0
#
#
# Outlier Treatment for  Bedroom2
# IQR for  Bedroom2 = 0.0
# Floor for  Bedroom2 = -3.0
# Cap for  Bedroom2 = 3.0
#
#
# Outlier Treatment for  Bathroom
# IQR for  Bathroom = 1.0
# Floor for  Bathroom = 0.5
# Cap for  Bathroom = 3.5
#
#
# Outlier Treatment for  Car
# IQR for  Car = 1.0
# Floor for  Car = 0.5
# Cap for  Car = 3.5
#
#
# Outlier Treatment for  Landsize
# IQR for  Landsize = 250.0
# Floor for  Landsize = 32.0
# Cap for  Landsize = 968.0
#
#
# Outlier Treatment for  BuildingArea
# IQR for  BuildingArea = 7.0
# Floor for  BuildingArea = -142.5
# Cap for  BuildingArea = 170.5
#
#
# Outlier Treatment for  YearBuilt
# IQR for  YearBuilt = 1966.0
# Floor for  YearBuilt = 2949.0
# Cap for  YearBuilt = 4915.0

# %%
#Identify variables that have non-linear trends. How many variables have non-linear trends? Transform them (as required)
plt.style.use('seaborn-whitegrid')
x=Mhousing_num['Rooms']
y=Mhousing_num['Price']
plt.plot(x,y,'o',color='black')

# %%
x=Mhousing_num['Bedroom2']
plt.plot(x,y,'o',color='black')

# %%
x=Mhousing_num['Bathroom']
plt.plot(x,y,'o',color='black')

# %%
x=Mhousing_num['Car']
plt.plot(x,y,'o',color='black')

# %%
x=Mhousing_num['Landsize']
plt.plot(x,y,'o',color='black')

# %%
x=Mhousing_num['BuildingArea']
plt.plot(x,y,'o',color='black')

# %%
Mhousing_num.corr()
# Out:
#                  Rooms     Price  Distance  Bedroom2  Bathroom       Car  \
# Rooms         1.000000  0.380622  0.319526  0.815368  0.446528  0.309311
# Price         0.380622  1.000000 -0.165154  0.285760  0.173880  0.098355
# Distance      0.319526 -0.165154  1.000000  0.281482  0.135119  0.222879
# Bedroom2      0.815368  0.285760  0.281482  1.000000  0.564183  0.373310
# Bathroom      0.446528  0.173880  0.135119  0.564183  1.000000  0.319768
# Car           0.309311  0.098355  0.222879  0.373310  0.319768  1.000000
# Landsize      0.053969  0.016094  0.104025  0.062880  0.045109  0.070678
# BuildingArea  0.086347  0.046019  0.055393  0.097622  0.090594  0.068776
# YearBuilt     0.061899  0.004251  0.005122  0.000087 -0.090649 -0.099578
# Lattitude    -0.123422 -0.112159 -0.031815 -0.007770  0.294638  0.143990
# Longtitude    0.123879  0.113773  0.030179  0.008283 -0.294106 -0.143784
#
#               Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude
# Rooms         0.053969      0.086347   0.061899  -0.123422    0.123879
# Price         0.016094      0.046019   0.004251  -0.112159    0.113773
# Distance      0.104025      0.055393   0.005122  -0.031815    0.030179
# Bedroom2      0.062880      0.097622   0.000087  -0.007770    0.008283
# Bathroom      0.045109      0.090594  -0.090649   0.294638   -0.294106
# Car           0.070678      0.068776  -0.099578   0.143990   -0.143784
# Landsize      1.000000      0.162780  -0.025846   0.006914   -0.006951
# BuildingArea  0.162780      1.000000  -0.032140   0.006482   -0.006442
# YearBuilt    -0.025846     -0.032140   1.000000  -0.491663    0.491427
# Lattitude     0.006914      0.006482  -0.491663   1.000000   -0.999949
# Longtitude   -0.006951     -0.006442   0.491427  -0.999949    1.000000

# %%
#Based on the above Scatter Plots & correlation matrix, it can be concluded that 
#    Rooms, Bedroom2, Bathroom & Car have weak positive correlation with Price.
#    Distance have weak weak negative correlation with Price
#    Landsize & Building Area do not have much correlation with Price. i.e, it is having non-linear trend & need to be transformed

Mhousing_P=Mhousing_num.loc[:,['Price','Landsize','BuildingArea']]
Mhousing_P['logLS']=np.log(Mhousing_P['Landsize'])
Mhousing_P['LS^2']=Mhousing_P['Landsize']**2
Mhousing_P['LS^3']=Mhousing_P['Landsize']**3
Mhousing_P['LSsqrt']=np.sqrt(Mhousing_P['Landsize'])

Mhousing_P['logBA']=np.log(Mhousing_P['BuildingArea'])
Mhousing_P['BA^2']=Mhousing_P['BuildingArea']**2
Mhousing_P['BA^3']=Mhousing_P['BuildingArea']**3
Mhousing_P['BAsqrt']=np.sqrt(Mhousing_P['BuildingArea'])
Mhousing_P.corr()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log
#   if sys.path[0] == '':
#                  Price  Landsize  BuildingArea     logLS      LS^2      LS^3  \
# Price         1.000000  0.016094      0.046019 -0.007127  0.003413  0.003000
# Landsize      0.016094  1.000000      0.162780  0.404674  0.836489  0.702911
# BuildingArea  0.046019  0.162780      1.000000  0.077098  0.075016  0.025421
# logLS        -0.007127  0.404674      0.077098  1.000000  0.139073  0.091174
# LS^2          0.003413  0.836489      0.075016  0.139073  1.000000  0.967224
# LS^3          0.003000  0.702911      0.025421  0.091174  0.967224  1.000000
# LSsqrt        0.106137  0.705139      0.137661  0.834776  0.378415  0.282098
# logBA         0.201155  0.054010      0.268926  0.189443  0.009528  0.004399
# BA^2          0.007720  0.162408      0.957517  0.045401  0.078550  0.026534
# BA^3          0.007220  0.162308      0.950725  0.044802  0.078593  0.026552
# BAsqrt        0.177324  0.109227      0.667384  0.172661  0.038232  0.013699
#
#                 LSsqrt     logBA      BA^2      BA^3    BAsqrt
# Price         0.106137  0.201155  0.007720  0.007220  0.177324
# Landsize      0.705139  0.054010  0.162408  0.162308  0.109227
# BuildingArea  0.137661  0.268926  0.957517  0.950725  0.667384
# logLS         0.834776  0.189443  0.045401  0.044802  0.172661
# LS^2          0.378415  0.009528  0.078550  0.078593  0.038232
# LS^3          0.282098  0.004399  0.026534  0.026552  0.013699
# LSsqrt        1.000000  0.229385  0.102600  0.102057  0.228397
# logBA         0.229385  1.000000  0.089699  0.085130  0.839317
# BA^2          0.102600  0.089699  1.000000  0.999579  0.469414
# BA^3          0.102057  0.085130  0.999579  1.000000  0.459597
# BAsqrt        0.228397  0.839317  0.469414  0.459597  1.000000

# %%
#Based on above correlation matrix, it can be concluded that
#     For Landsize, preferred transformation is LSsqrt  and
#     For BuildingArea, preferred transformation is logBA
Mhousing_num['LSsqrt']=np.sqrt(Mhousing_num['Landsize'])
Mhousing_num['logBA']=np.log(Mhousing_num['BuildingArea'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
#Standardization:Name the variables to be standardised before using a distance-based algorithm


#SOLUTION: All numeric variables should be standardised before applying distance based algorithm such as KNN method

         #using z-score method
int_columns=['Rooms','Price','Distance','Bedroom2','Bathroom','Car','Landsize','BuildingArea','YearBuilt','Lattitude','Longtitude']

from scipy.stats import zscore
Mhousing_num_z=Mhousing_num[int_columns].apply(zscore)
print(Mhousing_num_z)
# Out:
#           Rooms     Price  Distance  Bedroom2  Bathroom       Car  Landsize  \
# 0     -1.026567  0.359152 -1.296969 -1.217650 -1.088328 -0.886368 -0.297071
# 1     -1.026567  1.673006 -1.296969 -1.217650 -1.088328 -0.886368 -0.246606
# 2     -1.026567  0.312773 -1.296969 -1.217650 -1.088328 -2.033518 -0.277151
# 3      0.040261  0.359152 -1.296969 -0.013421  0.531377 -0.886368 -0.380738
# 4      0.040261  1.627155 -1.296969 -0.013421  0.531377 -2.033518 -0.291759
# 5      0.040261 -0.252717 -1.296969 -0.013421  0.531377 -0.886368 -0.318320
# 6      1.107088  2.039810 -1.296969 -0.013421 -1.088328  0.260782 -0.301056
# 7      1.107088  0.359152 -1.296969 -0.013421  0.531377  0.260782 -0.115130
# 8     -1.026567  0.359152 -1.296969  1.190807 -1.088328  0.260782 -0.247270
# 9     -1.026567  0.359152 -1.296969 -0.013421  0.531377 -0.886368 -0.246606
# 10    -1.026567  0.025443 -1.296969 -1.217650 -1.088328 -2.033518 -0.260550
# 12    -1.026567  0.359152 -1.296969 -1.217650  0.531377 -0.886368  2.469235
# 13     1.107088  0.359152 -1.296969  3.599265  0.531377 -2.033518 -0.228013
# 14    -1.026567  2.149852 -1.296969 -1.217650 -1.088328  0.260782 -0.210749
# 15     0.040261  0.205788 -1.296969 -0.013421  0.531377  0.260782  0.013026
# 16    -1.026567 -0.573671 -1.296969 -0.013421  0.531377  0.260782  0.013026
# 17    -2.093394 -1.933904 -1.296969 -2.421879 -1.088328 -0.886368 -0.380738
# 18    -1.026567  0.502289 -1.296969 -0.013421 -1.088328  0.260782 -0.234654
# 19    -1.026567 -1.194182 -1.296969 -0.013421  0.531377  0.260782  0.013026
# 20    -1.026567  0.359152 -1.296969 -1.217650 -1.088328 -0.886368 -0.263870
# 21    -1.026567 -0.527820 -1.296969 -0.013421  0.531377  0.260782  0.013026
# 22    -2.093394 -1.380640 -1.296969 -0.013421  0.531377  0.260782  0.013026
# 23    -1.026567 -0.711222 -1.296969 -1.217650  0.531377 -0.886368 -0.380738
# 24     0.040261  1.275634 -1.296969 -0.013421  0.531377  0.260782 -0.238638
# 25    -1.026567 -0.558387 -1.296969 -1.217650  0.531377 -0.886368 -0.380738
# 27    -2.093394 -1.322563 -1.296969 -0.013421  0.531377  0.260782  0.013026
# 28    -1.026567  0.733070 -1.296969 -1.217650 -1.088328 -0.886368 -0.251254
# 29    -2.093394 -1.502909 -1.296969 -2.421879 -1.088328 -0.886368 -0.380738
# 30    -1.026567  1.153366 -1.296969 -1.217650 -1.088328  0.260782 -0.222701
# 31     0.040261  0.359152 -1.296969 -0.013421  0.531377  0.260782 -0.380738
# ...         ...       ...       ...       ...       ...       ...       ...
# 34826  1.107088 -0.307738 -0.719255  1.190807 -1.088328 -0.886368 -0.235318
# 34827  1.107088  0.499232 -0.719255  1.190807 -1.088328  1.407932 -0.136379
# 34828  0.040261 -0.099882 -0.719255 -0.013421 -1.088328  0.260782 -0.075289
# 34829  0.040261  0.359152 -1.152541 -0.013421  0.531377  0.260782  0.013026
# 34830  0.040261  0.664294 -1.152541 -0.013421  0.531377  0.260782  0.069468
# 34831  1.107088 -0.787640  0.725032  1.190807  0.531377  3.702232 -0.008887
# 34832  1.107088 -0.744846  0.725032 -0.013421  0.531377  0.260782  0.013026
# 34833  1.107088  0.010159  0.725032  1.190807  0.531377  0.260782  0.130557
# 34834  1.107088  0.359152  0.725032  1.190807  0.531377  0.260782  0.093372
# 34835  0.040261  0.359152  0.725032 -0.013421  0.531377  0.260782  0.068803
# 34836  2.173916  1.428470  0.725032  2.395036  0.531377  0.260782  0.109973
# 34838 -1.026567 -1.475398 -0.719255 -0.013421  0.531377  0.260782  0.013026
# 34839 -1.026567 -1.398981 -0.719255 -0.013421  0.531377  0.260782  0.013026
# 34840 -1.026567 -1.261429 -0.719255 -0.013421  0.531377  0.260782  0.013026
# 34841 -1.026567  0.022386 -0.719255 -1.217650  0.531377 -0.886368 -0.299728
# 34842  0.040261  1.428470 -0.719255 -0.013421  0.531377  0.260782 -0.164932
# 34843  0.040261 -0.313851 -0.719255 -0.013421 -1.088328  0.260782 -0.151651
# 34844 -2.093394 -1.505965 -1.008112 -0.013421  0.531377  0.260782  0.013026
# 34845  1.107088  0.359152 -1.008112  1.190807  2.151082  0.260782 -0.195476
# 34846  1.107088 -0.925192  2.024890  1.190807  0.531377  0.260782 -0.123098
# 34847  0.040261 -1.322563  2.024890 -0.013421  0.531377  0.260782 -0.126418
# 34848  1.107088 -0.952702  2.024890  1.190807  0.531377  0.260782 -0.131731
# 34849  0.040261 -1.108594  2.024890 -0.013421  0.531377  0.260782 -0.112474
# 34850  0.040261  0.359152  2.024890 -0.013421  0.531377  0.260782 -0.202781
# 34851  0.040261  0.514515 -0.719255 -0.013421 -1.088328  0.260782 -0.189500
# 34852  1.107088  1.673006 -0.719255  1.190807 -1.088328  1.407932  0.013026
# 34853 -1.026567 -0.136562 -0.719255 -1.217650  0.531377 -0.886368 -0.315664
# 34854 -1.026567 -0.695939 -0.719255 -1.217650 -1.088328  0.260782 -0.234654
# 34855  0.040261  0.633727 -0.719255 -0.013421  0.531377  0.260782  0.013026
# 34856 -1.026567  0.266922 -0.719255 -1.217650 -1.088328 -2.033518 -0.214733
#
#        BuildingArea  YearBuilt  Lattitude  Longtitude
# 0          0.011963  -0.887783  -0.553855    0.546791
# 1          0.011963  -0.887783  -0.553855    0.546791
# 2         -0.299706   1.056978  -0.553855    0.546791
# 3          0.011963  -0.887783  -0.553855    0.563094
# 4         -0.026515   1.056978  -0.553855    0.546791
# 5          0.011963  -0.887783  -0.553855    0.546791
# 6         -0.057297   1.173664  -0.553855    0.546791
# 7          0.242830   1.165475  -0.553855    0.546791
# 8          0.011963   1.056978  -0.553855    0.546791
# 9          0.011963   1.056978  -0.553855    0.546791
# 10         0.011963  -0.887783  -0.553855    0.546791
# 12        -0.288163   1.168546  -0.553855    0.546791
# 13        -0.038058   1.016036  -0.553855    0.546791
# 14        -0.191969   1.046743  -0.553855    0.546791
# 15         0.011963  -0.887783   1.800737   -1.800753
# 16         0.011963  -0.887783   1.800737   -1.800753
# 17         0.011963  -0.887783  -0.553855    0.546791
# 18        -0.315097   1.056978  -0.553855    0.546791
# 19         0.011963  -0.887783   1.800737   -1.800753
# 20        -0.295859   1.082567  -0.553855    0.546791
# 21         0.011963  -0.887783   1.800737   -1.800753
# 22         0.011963  -0.887783   1.800737   -1.800753
# 23         0.011963  -0.887783  -0.553855    0.563094
# 24         0.127396   1.164452  -0.553855    0.546791
# 25        -0.241990   1.168546  -0.553855    0.546791
# 27         0.011963  -0.887783   1.800737   -1.800753
# 28         0.011963  -0.887783  -0.553855    0.546791
# 29         0.011963  -0.887783  -0.553855    0.546791
# 30        -0.230446   1.046743  -0.553855    0.546791
# 31        -0.107318   1.169570  -0.553855    0.546791
# ...             ...        ...        ...         ...
# 34826     -0.168882   1.067214  -0.553855    0.546791
# 34827      0.011963  -0.887783  -0.553855    0.546791
# 34828     -0.172730   1.097921  -0.553855    0.546791
# 34829      0.011963  -0.887783   1.800737   -1.800753
# 34830      0.011963  -0.887783  -0.553855    0.546791
# 34831     -0.034210   1.138863  -0.553855    0.546791
# 34832      0.011963  -0.887783   1.800737   -1.800753
# 34833      0.011963  -0.887783  -0.553855    0.563094
# 34834      0.011963  -0.887783  -0.553855    0.563094
# 34835      0.011963  -0.887783  -0.553855    0.563094
# 34836      0.523717   1.138863  -0.553855    0.563094
# 34838      0.011963  -0.887783   1.800737   -1.800753
# 34839      0.011963  -0.887783   1.800737   -1.800753
# 34840      0.011963  -0.887783   1.800737   -1.800753
# 34841      0.011963   1.158310  -0.553855    0.546791
# 34842      0.004268   1.154216  -0.553855    0.546791
# 34843      0.011963   1.107133  -0.553855    0.546791
# 34844      0.011963  -0.887783   1.800737   -1.800753
# 34845      0.308242   1.168546  -0.553855    0.546791
# 34846      0.011963  -0.887783  -0.553855    0.563094
# 34847     -0.149643   1.175711  -0.553855    0.563094
# 34848      0.011963  -0.887783  -0.553855    0.563094
# 34849      0.004268   1.171617  -0.553855    0.563094
# 34850     -0.084231   1.175711  -0.553855    0.563094
# 34851      0.011963  -0.887783  -0.553855    0.546791
# 34852      0.011963  -0.887783  -0.553855    0.546791
# 34853     -0.203512   1.177758  -0.553855    0.546791
# 34854     -0.141948   1.159334  -0.553855    0.546791
# 34855      0.011963  -0.887783   1.800737   -1.800753
# 34856     -0.207360   1.087685  -0.553855    0.546791
#
# [32301 rows x 11 columns]

# %%
#Dummy encoding :Identify the number of dummy variables to be created for the variable steel.

#SOLUTION: There is no variable called as 'steel' in the data set. Hence selecting variable 'Suburb' to work on.

print("Dummy variables to be created for variable Suburb :")
Mhousing['Suburb'].value_counts()

#dummies=pd.get_dummies(Mhousing['Suburb'])
#dummies.head()
# Out:
# Dummy variables to be created for variable Suburb :
# Reservoir             844
# Bentleigh East        583
# Richmond              552
# Glen Iris             491
# Preston               485
# Kew                   467
# Brighton              456
# Brunswick             444
# South Yarra           435
# Hawthorn              428
# Northcote             424
# Camberwell            423
# Balwyn North          420
# Essendon              409
# Coburg                405
# Glenroy               400
# Brighton East         393
# Pascoe Vale           378
# St Kilda              374
# Port Melbourne        371
# Malvern East          369
# Prahran               336
# Thornbury             322
# Balwyn                319
# Bentleigh             319
# Yarraville            304
# Surrey Hills          293
# Elwood                288
# Moonee Ponds          285
# Hawthorn East         284
#                      ...
# Upwey                   2
# Silvan                  2
# Wattle Glen             2
# Darley                  2
# Beaconsfield Upper      2
# Montrose                2
# Gisborne South          2
# Lynbrook                2
# Hurstbridge             2
# Healesville             2
# Wandin North            1
# Yarra Glen              1
# Eynesbury               1
# Fawkner Lot             1
# Wildwood                1
# Ferny Creek             1
# Guys Hill               1
# Cranbourne East         1
# Bulla                   1
# Hopetoun Park           1
# Olinda                  1
# croydon                 1
# Kalkallo                1
# Botanic Ridge           1
# Menzies Creek           1
# Avonsleigh              1
# Monbulk                 1
# Belgrave                1
# Coldstream              1
# viewbank                1
# Name: Suburb, Length: 351, dtype: int64
